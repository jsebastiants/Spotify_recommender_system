# %%
# Import Libraries
# !pip install psycopg2

import requests
import pandas as pd
import datetime
import psycopg2 as ps
# Out:
# Requirement already satisfied: psycopg2 in c:\users\sebastian\anaconda3\lib\site-packages (2.9.5)

# %%
# Calling the API
page_Token = 'BQA--jRAGXILVaqPfeQGEwcGZF3aixsYaIH_y7XOGbYs9AEy6yMA2Y1PCE9N7nFaueDB544FX4niZcP2HCpsYw-_EpikrrhU-m49peX6qQ_tJOSIQL1_mfdUP6rPP1yNhRNFM_ZRqE8kKbmLlmHJB4YUzzNp39S10mKJI34ZaMATH2ERewDRjw7nxmRKC597C0ZTJQ'
headers = {
    "Accept": "application/json",
    "Content_type": "application/json",
    "Authorization": "Bearer {token}".format(token=page_Token)
}

#Spotify uses unix timestamp
today = datetime.datetime.now()
yesterday = today - datetime.timedelta(hours=1)
yesterday_unix_timestamp = int(yesterday.timestamp())*1000

url_time= 'https://api.spotify.com/v1/me/player/recently-played?after={time}'.format(time=yesterday_unix_timestamp)
r_time = requests.get(url_time, headers=headers).json()
r_time['items'][0]['played_at']
# Out:
# '2023-02-01T00:03:38.766Z'

# %%
uri= []
song_names= []
artist_names= []
popularity= []

for song in r_time['items']:
    uri.append(song['track']['id'])
    song_names.append(song['track']['name'])
    artist_names.append(song['track']['artists'][0]['name'])
    popularity.append(song['track']['popularity'])

song_dict= {
    'id': uri,
    'song_names': song_names,
    'artist_names': artist_names,
    'uri': uri,
    'popularity': popularity,
}
    
# We drop duplicates based on uri column
song_df = pd.DataFrame(song_dict, columns=['uri', 'song_names', 'artist_names', 'popularity'])
song_df = song_df.drop_duplicates()
song_df
# Out:
#                        uri             song_names  artist_names  popularity
# 0   0EDzxUaUO4j9knZsytC3V8                  Brown     Kyle Dion          51
# 1   4Ku4jFPD4J7UxdjG0xpjPf              Starchild        Elujay          40
# 2   0GEEPePzBTplRekjTt04N0     Count My Blessings     Anna Wise          40
# 3   7yeWt7sq2oRlEZWv880u9E                  CLOUD       Monsune          44
# 4   5wv2XK6ms7KBBVDD1cOwlx          Cool with You         Her's          59
# 5   1Omt5bfz1tZUCqd26HxbS0                 Beyond  Leon Bridges          70
# 6   6tDDoYIxWvMLTdKpjFkc1B              telepatía    Kali Uchis          79
# 7   5x3v1Td2EkrUJfscZdb6zJ            Got My Back         RIMON          44
# 8   4Nw7kywWurWS6ceinn1cHK            Baby Powder     Jenevieve          66
# 9   1pYXiImb0JtzMKHtdWtw9n                    Blu        Elujay          36
# 10  2JUQ7mV1AHk2owXLydmN4Z           Love's Train    Bruno Mars          57
# 11  227jTRlttZd3Qjoe1cdtmb           Lava/Treacle         ELIZA          45
# 12  18nowS51G3slipQrcRH4bt             Discreción    Girl Ultra          38
# 13  4GR2VDGNBpGyE4wZy0VTSj                 Malibú    Jesse Baez          52
# 14  1NlWBpNYAnFT7gMGyC0Y1M  Sandstorm (feat. JID)        Mereba          60
# 15  3mMduiD8yb4IaS5tZKqSZy              Motorbike  Leon Bridges          54

# %%
BASE_URL = 'https://api.spotify.com/v1/'
feature_dict = {}
track_uris = song_df['uri'].to_list()

for t_uri in track_uris:
    
    feature_dict[t_uri] = {'popularity': 0,
                         'acousticness': 0,
                         'danceability': 0,
                         'duration_ms': 0,
                         'energy': 0,
                         'liveness': 0,
                         'loudness': 0,
                         'mode': 0,
                         'speechiness': 0,
                         'instrumentalness': 0,
                         'tempo': 0,
                         'valence': 0}
    
    r = requests.get(BASE_URL + 'tracks/' + t_uri, headers=headers)
    r = r.json()
    feature_dict[t_uri]['popularity'] = r['popularity']
    
    s = requests.get(BASE_URL + 'audio-features/' + t_uri, headers=headers)
    s = s.json()
    feature_dict[t_uri]['acousticness'] = s['acousticness']
    feature_dict[t_uri]['danceability'] = s['danceability']
    feature_dict[t_uri]['duration_ms'] = s['duration_ms']
    feature_dict[t_uri]['energy'] = s['energy']
    feature_dict[t_uri]['liveness'] = s['liveness']
    feature_dict[t_uri]['loudness'] = s['loudness']
    feature_dict[t_uri]['mode'] = s['mode']
    feature_dict[t_uri]['speechiness'] = s['speechiness']
    feature_dict[t_uri]['instrumentalness'] = s['instrumentalness']
    feature_dict[t_uri]['tempo'] = s['tempo']
    feature_dict[t_uri]['valence'] = s['valence']

# %%
df_features = pd.DataFrame.from_dict(feature_dict, orient='index')
df_features.insert(0, 'uri', df_features.index)
df_features.reset_index(inplace=True, drop=True)

df_features.head(20)
# Out:
#                        uri  popularity  acousticness  danceability  \
# 0   0EDzxUaUO4j9knZsytC3V8          51        0.0740         0.546
# 1   4Ku4jFPD4J7UxdjG0xpjPf          40        0.1250         0.503
# 2   0GEEPePzBTplRekjTt04N0          40        0.2980         0.574
# 3   7yeWt7sq2oRlEZWv880u9E          44        0.1610         0.593
# 4   5wv2XK6ms7KBBVDD1cOwlx          59        0.0124         0.534
# 5   1Omt5bfz1tZUCqd26HxbS0          70        0.2290         0.581
# 6   6tDDoYIxWvMLTdKpjFkc1B          79        0.1120         0.653
# 7   5x3v1Td2EkrUJfscZdb6zJ          44        0.1390         0.661
# 8   4Nw7kywWurWS6ceinn1cHK          66        0.2380         0.799
# 9   1pYXiImb0JtzMKHtdWtw9n          36        0.5290         0.668
# 10  2JUQ7mV1AHk2owXLydmN4Z          57        0.0396         0.711
# 11  227jTRlttZd3Qjoe1cdtmb          45        0.3990         0.795
# 12  18nowS51G3slipQrcRH4bt          38        0.7250         0.730
# 13  4GR2VDGNBpGyE4wZy0VTSj          52        0.0399         0.775
# 14  1NlWBpNYAnFT7gMGyC0Y1M          60        0.5900         0.637
# 15  3mMduiD8yb4IaS5tZKqSZy          54        0.1580         0.721
#
#     duration_ms  energy  liveness  loudness  mode  speechiness  \
# 0        234759   0.698    0.0613    -4.677     1       0.0981
# 1        190153   0.615    0.0881    -6.545     0       0.2320
# 2        185621   0.531    0.6700    -7.912     0       0.4730
# 3        180375   0.499    0.2560   -10.189     0       0.0441
# 4        375656   0.620    0.2960    -6.775     1       0.0504
# 5        240600   0.687    0.1090    -5.400     1       0.1050
# 6        160191   0.524    0.2030    -9.016     0       0.0502
# 7        204901   0.463    0.0628   -11.754     0       0.0474
# 8        176760   0.452    0.0878    -7.641     0       0.0466
# 9        215030   0.546    0.1180    -7.872     0       0.0415
# 10       307014   0.605    0.1040    -9.801     0       0.0310
# 11       201253   0.313    0.0851   -13.012     1       0.1840
# 12       299550   0.447    0.0471   -10.170     1       0.0591
# 13       220400   0.345    0.1580    -9.578     1       0.0605
# 14       179027   0.512    0.0712   -10.027     1       0.0978
# 15       188617   0.485    0.1070   -11.213     0       0.0681
#
#     instrumentalness    tempo  valence
# 0           0.000129   72.417    0.617
# 1           0.000140   82.533    0.494
# 2           0.000001   89.873    0.658
# 3           0.088500   82.983    0.548
# 4           0.000736  106.986    0.547
# 5           0.000000   76.014    0.187
# 6           0.000000   83.970    0.553
# 7           0.000000  135.945    0.392
# 8           0.000133   78.461    0.732
# 9           0.000001   76.002    0.375
# 10          0.000023  140.981    0.807
# 11          0.535000  156.006    0.676
# 12          0.000000   73.971    0.676
# 13          0.000000  139.943    0.516
# 14          0.000464  109.492    0.330
# 15          0.275000  150.027    0.614

# %%
#Vamos a unir las tablas
spotify_df = pd.merge(song_df, df_features)
spotify_df = spotify_df.drop('uri', axis=1)
spotify_df
# Out:
#                song_names  artist_names  popularity  acousticness  \
# 0                   Brown     Kyle Dion          51        0.0740
# 1               Starchild        Elujay          40        0.1250
# 2      Count My Blessings     Anna Wise          40        0.2980
# 3                   CLOUD       Monsune          44        0.1610
# 4           Cool with You         Her's          59        0.0124
# 5                  Beyond  Leon Bridges          70        0.2290
# 6               telepatía    Kali Uchis          79        0.1120
# 7             Got My Back         RIMON          44        0.1390
# 8             Baby Powder     Jenevieve          66        0.2380
# 9                     Blu        Elujay          36        0.5290
# 10           Love's Train    Bruno Mars          57        0.0396
# 11           Lava/Treacle         ELIZA          45        0.3990
# 12             Discreción    Girl Ultra          38        0.7250
# 13                 Malibú    Jesse Baez          52        0.0399
# 14  Sandstorm (feat. JID)        Mereba          60        0.5900
# 15              Motorbike  Leon Bridges          54        0.1580
#
#     danceability  duration_ms  energy  liveness  loudness  mode  speechiness  \
# 0          0.546       234759   0.698    0.0613    -4.677     1       0.0981
# 1          0.503       190153   0.615    0.0881    -6.545     0       0.2320
# 2          0.574       185621   0.531    0.6700    -7.912     0       0.4730
# 3          0.593       180375   0.499    0.2560   -10.189     0       0.0441
# 4          0.534       375656   0.620    0.2960    -6.775     1       0.0504
# 5          0.581       240600   0.687    0.1090    -5.400     1       0.1050
# 6          0.653       160191   0.524    0.2030    -9.016     0       0.0502
# 7          0.661       204901   0.463    0.0628   -11.754     0       0.0474
# 8          0.799       176760   0.452    0.0878    -7.641     0       0.0466
# 9          0.668       215030   0.546    0.1180    -7.872     0       0.0415
# 10         0.711       307014   0.605    0.1040    -9.801     0       0.0310
# 11         0.795       201253   0.313    0.0851   -13.012     1       0.1840
# 12         0.730       299550   0.447    0.0471   -10.170     1       0.0591
# 13         0.775       220400   0.345    0.1580    -9.578     1       0.0605
# 14         0.637       179027   0.512    0.0712   -10.027     1       0.0978
# 15         0.721       188617   0.485    0.1070   -11.213     0       0.0681
#
#     instrumentalness    tempo  valence
# 0           0.000129   72.417    0.617
# 1           0.000140   82.533    0.494
# 2           0.000001   89.873    0.658
# 3           0.088500   82.983    0.548
# 4           0.000736  106.986    0.547
# 5           0.000000   76.014    0.187
# 6           0.000000   83.970    0.553
# 7           0.000000  135.945    0.392
# 8           0.000133   78.461    0.732
# 9           0.000001   76.002    0.375
# 10          0.000023  140.981    0.807
# 11          0.535000  156.006    0.676
# 12          0.000000   73.971    0.676
# 13          0.000000  139.943    0.516
# 14          0.000464  109.492    0.330
# 15          0.275000  150.027    0.614

# %%
def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)

    except mysql.connector.OperationalError as e:
        raise e
    else:
        print('Connected!')
    return conn

# %%
host_name = 'localhost'
dbname = "Spotify_data"
port = '5432'
username = 'postgres'
password = 'llbastian_torresll'
conn= None

conn = connect_to_db(host_name, dbname, port, username, password)
# Out:
# Connected!

# %%
def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS songs(
                        song_names VARCHAR(200) PRIMARY KEY,
                        artist_names VARCHAR(200) NOT NULL,
                        popularity INT NOT NULL,
                        acousticness FLOAT NOT NULL,
                        danceability FLOAT NOT NULL,
                        duration_ms INT NOT NULL,
                        energy FLOAT NOT NULL,
                        liveness FLOAT NOT NULL,
                        loudness FLOAT NOT NULL,
                        mode INT NOT NULL,
                        speechiness FLOAT NOT NULL,
                        instrumentalness FLOAT NOT NULL,
                        tempo FLOAT NOT NULL, 
                        valence FLOAT NOT NULL
                        );""")

    curr.execute(create_table_command)

# %%
#write insert command 
def insert_into_table(curr,song_names, artist_names, popularity, acousticness, danceability, duration_ms, energy, liveness, loudness, mode, speechiness, instrumentalness, tempo, valence):
    insert_into_songs = ("""INSERT INTO songs (song_names, artist_names, popularity, acousticness, danceability, duration_ms, energy, liveness, loudness, mode, speechiness, instrumentalness, tempo, valence)
    VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);""")

    row_to_insert = (song_names, artist_names, popularity, acousticness, danceability, duration_ms, energy, liveness, loudness, mode, speechiness, instrumentalness, tempo, valence)

    curr.execute(insert_into_songs, row_to_insert)

# %%
#check_song_exist
def check_if_song_exists(curr, song_names):
    query = ("""SELECT song_names FROM songs WHERE song_names = %s""")
    curr.execute(query, (song_names,))
    
    return curr.fetchone() is not None

# %%
def append_from_df_to_db(curr, spotify_df):
    for i, row in spotify_df.iterrows():
          insert_into_table(curr, row['song_names'], row['artist_names'], row['popularity'], row['acousticness'], row['danceability'], row['duration_ms'], row['energy'], row['liveness'], row['loudness'], row['mode'], row['speechiness'], row['instrumentalness'], row['tempo'], row['valence'])

# %%
#Check if song exist in the db
def update_db(curr, spotify_df):
    tmp_df = pd.DataFrame(columns=['song_names', 'artist_names', 'popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'liveness', 'loudness', 'mode', 'speechiness', 'instrumentalness', 'tempo', 'valence'])

    for i, row in spotify_df.iterrows():
          if check_if_song_exists(curr, row['song_names']): #If song already exists then we'll pass
            pass
          else:  #The song doesn't exists so we'll append to the db table
            tmp_df = tmp_df.append(row)

    return tmp_df

# %%
curr = conn.cursor()

# %%
create_table(curr)

# %%
new_songs_df = update_db(curr, spotify_df)
conn.commit()
# Out:
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)
# C:\Users\Sebastian\AppData\Local\Temp\ipykernel_6508\1661511982.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tmp_df = tmp_df.append(row)

# %%
new_songs_df
# Out:
#            song_names  artist_names popularity  acousticness  danceability  \
# 0               Brown     Kyle Dion         51        0.0740         0.546
# 1           Starchild        Elujay         40        0.1250         0.503
# 2  Count My Blessings     Anna Wise         40        0.2980         0.574
# 3               CLOUD       Monsune         44        0.1610         0.593
# 4       Cool with You         Her's         59        0.0124         0.534
# 5              Beyond  Leon Bridges         70        0.2290         0.581
# 6           telepatía    Kali Uchis         79        0.1120         0.653
# 7         Got My Back         RIMON         44        0.1390         0.661
# 8         Baby Powder     Jenevieve         66        0.2380         0.799
# 9                 Blu        Elujay         36        0.5290         0.668
#
#   duration_ms  energy  liveness  loudness mode  speechiness  instrumentalness  \
# 0      234759   0.698    0.0613    -4.677    1       0.0981          0.000129
# 1      190153   0.615    0.0881    -6.545    0       0.2320          0.000140
# 2      185621   0.531    0.6700    -7.912    0       0.4730          0.000001
# 3      180375   0.499    0.2560   -10.189    0       0.0441          0.088500
# 4      375656   0.620    0.2960    -6.775    1       0.0504          0.000736
# 5      240600   0.687    0.1090    -5.400    1       0.1050          0.000000
# 6      160191   0.524    0.2030    -9.016    0       0.0502          0.000000
# 7      204901   0.463    0.0628   -11.754    0       0.0474          0.000000
# 8      176760   0.452    0.0878    -7.641    0       0.0466          0.000133
# 9      215030   0.546    0.1180    -7.872    0       0.0415          0.000001
#
#      tempo  valence
# 0   72.417    0.617
# 1   82.533    0.494
# 2   89.873    0.658
# 3   82.983    0.548
# 4  106.986    0.547
# 5   76.014    0.187
# 6   83.970    0.553
# 7  135.945    0.392
# 8   78.461    0.732
# 9   76.002    0.375

# %%
append_from_df_to_db(curr, new_songs_df)
conn.commit()

# %%
#view data in db table

curr.execute("SELECT * FROM songs")
print(curr.fetchall())
# Out:
# [('STAY (with Justin Bieber)', 'The Kid LAROI', 75, 0.0383, 0.591, 141806, 0.764, 0.103, -5.484, 1, 0.0483, 0.0, 169.928, 0.478), ('AMG', 'Natanael Cano', 86, 0.152, 0.772, 174943, 0.73, 0.274, -6.657, 0, 0.0972, 0.000107, 136.175, 0.786), ('Me Porto Bonito', 'Bad Bunny', 91, 0.0901, 0.911, 178567, 0.712, 0.0933, -5.105, 0, 0.0817, 2.68e-05, 92.005, 0.425), ('Rich Flex', 'Drake', 91, 0.0503, 0.561, 239360, 0.52, 0.355, -9.342, 0, 0.244, 1.86e-06, 153.15, 0.424), ('Until I Found You (with Em Beihold) - Em Beihold Version', 'Stephen Sanchez', 90, 0.777, 0.551, 176440, 0.55, 0.202, -5.339, 1, 0.0286, 0.0, 101.19, 0.342), ('Mockingbird', 'Eminem', 90, 0.209, 0.637, 250760, 0.678, 0.156, -3.798, 1, 0.266, 0.0, 84.039, 0.254), ('I Wanna Be Yours', 'Arctic Monkeys', 90, 0.136, 0.464, 183956, 0.417, 0.0974, -9.345, 0, 0.0256, 0.022, 67.528, 0.479), ('Made You Look', 'Meghan Trainor', 91, 0.345, 0.838, 134256, 0.525, 0.0771, -3.562, 1, 0.0665, 1.92e-06, 144.981, 0.884), ('Bebe Dame', 'Fuerza Regida', 78, 0.299, 0.529, 271862, 0.602, 0.0716, -4.629, 1, 0.0458, 0.0, 157.643, 0.756), ("I Ain't Worried", 'OneRepublic', 91, 0.0826, 0.704, 148486, 0.797, 0.0546, -5.927, 1, 0.0475, 0.000745, 139.994, 0.825), ('Another Love', 'Tom Odell', 90, 0.695, 0.445, 244360, 0.537, 0.0944, -8.532, 0, 0.04, 1.65e-05, 122.769, 0.131), ('OMG', 'NewJeans', 89, 0.357, 0.804, 212253, 0.771, 0.108, -4.067, 0, 0.0433, 3.07e-06, 126.956, 0.739), ('Hey Mor', 'Ozuna', 89, 0.00302, 0.901, 196600, 0.589, 0.0992, -6.713, 0, 0.289, 0.000237, 98.002, 0.399), ('golden hour', 'JVKE', 88, 0.653, 0.515, 209260, 0.593, 0.25, -4.801, 1, 0.0322, 0.162, 94.467, 0.153), ('Ditto', 'NewJeans', 90, 0.027, 0.814, 185507, 0.641, 0.0993, -5.957, 0, 0.111, 0.0, 133.854, 0.183), ('Die For You', 'The Weeknd', 86, 0.111, 0.586, 260253, 0.525, 0.134, -7.163, 0, 0.0615, 0.0, 133.629, 0.508), ('Sure Thing', 'Miguel', 90, 0.0267, 0.684, 195373, 0.607, 0.191, -8.127, 0, 0.1, 0.000307, 81.001, 0.498), ('Quevedo: Bzrp Music Sessions, Vol. 52', 'Bizarrap', 93, 0.0125, 0.621, 198938, 0.782, 0.23, -5.548, 1, 0.044, 0.033, 128.033, 0.55), ('Here With Me', 'd4vd', 91, 0.534, 0.574, 242485, 0.469, 0.128, -8.209, 1, 0.0254, 9.21e-05, 132.023, 0.288), ('La Jumpa', 'Arcángel', 86, 0.111, 0.887, 196800, 0.234, 0.13, -14.52, 1, 0.178, 0.67, 140.02, 0.197), ('Feliz Cumpleaños Ferxxo', 'Feid', 85, 0.0863, 0.865, 155960, 0.573, 0.305, -5.501, 1, 0.0678, 0.0, 94.999, 0.563), ('Escapism.', 'RAYE', 81, 0.138, 0.538, 272373, 0.742, 0.0934, -5.355, 1, 0.114, 4.67e-05, 96.107, 0.25), ('Anti-Hero', 'Taylor Swift', 93, 0.13, 0.637, 200690, 0.643, 0.142, -6.571, 1, 0.0519, 1.8e-06, 97.008, 0.533), ('Calm Down (with Selena Gomez)', 'Rema', 92, 0.382, 0.801, 239318, 0.806, 0.114, -5.206, 1, 0.0381, 0.000669, 106.999, 0.802), ("I'm Good (Blue)", 'David Guetta', 94, 0.00383, 0.561, 175238, 0.965, 0.371, -3.673, 0, 0.0343, 7.07e-06, 128.04, 0.304), ('La Bachata', 'Manuel Turizo', 94, 0.583, 0.835, 162638, 0.679, 0.218, -5.329, 0, 0.0364, 1.98e-06, 124.98, 0.85), ('As It Was', 'Harry Styles', 89, 0.342, 0.52, 167303, 0.731, 0.311, -5.338, 0, 0.0557, 0.00101, 173.93, 0.662), ('Unholy (feat. Kim Petras)', 'Sam Smith', 63, 0.011, 0.712, 156943, 0.463, 0.301, -7.399, 1, 0.0797, 2.96e-06, 131.199, 0.206), ("Creepin' (with The Weeknd & 21 Savage)", 'Metro Boomin', 95, 0.417, 0.715, 221520, 0.62, 0.0822, -6.005, 0, 0.0484, 0.0, 97.95, 0.172), ('Kill Bill', 'SZA', 92, 0.0521, 0.644, 153947, 0.735, 0.161, -5.747, 1, 0.0391, 0.144, 88.98, 0.418), ('Shakira: Bzrp Music Sessions, Vol. 53', 'Bizarrap', 97, 0.274, 0.778, 218289, 0.632, 0.0915, -5.6, 0, 0.0493, 0.0, 122.104, 0.498), ('Flowers', 'Miley Cyrus', 100, 0.0632, 0.707, 200455, 0.681, 0.0322, -4.325, 1, 0.0668, 5.15e-06, 117.999, 0.646), ('Peep Shit', 'Patient Zero Beats', 52, 0.701, 0.777, 140179, 0.254, 0.117, -15.706, 0, 0.11, 0.768, 84.014, 0.65), ('So Alone', 'Midnight Son of GOD 82020', 58, 0.769, 0.576, 205938, 0.399, 0.119, -9.276, 0, 0.419, 4.69e-05, 91.583, 0.434), ('Pu ...
